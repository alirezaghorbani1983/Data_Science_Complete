# %%
# import csv

# # data
# rows = [
#     ['id', 'name', 'age', 'child', 'salary'],
#     [102, 'ali', 32, 5, 12000],
#     [103, 'naser', 33, 4, 15000],
#     [104, 'vahid', 30, 3, 15000],
#     [105, 'ali', 38, 5, 17000],
#     [106, 'amir', 37, 3, 18000],
#     [107, 'saeed', 26, 2, 16000],
#     [108, 'reza', 40, 2, 21000],
# ]

# # write csv 
# with open('1.csv', mode='w', newline='') as file:
#     writer = csv.writer(file)
#     writer.writerows(rows)

# print("file is made.")

# %% [markdown]
# ## make a csv file with usage of Pandas

# %%
import pandas as pd

# create a DataFrame
df = pd.DataFrame({
    'id': [102, 103, 104, 105, 106, 107, 108],
    'name': ['ali', 'naser', 'vahid', 'ali', 'amir', 'saeed', 'reza'],
    'age': [32, 33, 30, 38, 37, 26, 40],
    'child': [5, 4, 3, 5, 3, 2, 2],
    'salary': [12000, 15000, 15000, 17000, 12000, 16000, 21000]
})

# save the csv file
df.to_csv('1.csv', index=False)

df = pd.read_csv('1.csv', header = None)

print(df)
# Out:
#      0      1    2      3       4
# 0   id   name  age  child  salary
# 1  102    ali   32      5   12000
# 2  103  naser   33      4   15000
# 3  104  vahid   30      3   15000
# 4  105    ali   38      5   17000
# 5  106   amir   37      3   12000
# 6  107  saeed   26      2   16000
# 7  108   reza   40      2   21000

# %%
import statistics as st



f = open("1.csv","r")
l = []
next(f)

for line in f:
    l.append(float(line.split(',')[4]))

print(l)
# Out:
# [12000.0, 15000.0, 15000.0, 17000.0, 12000.0, 16000.0, 21000.0]

# %%
# mean of employee's incomes

print(st.mean(l))
# Out:
# 15428.57142857143

# %%
# sum of the employee's incomes

print(sum(l))
# Out:
# 108000.0

# %%
print(min(l))
# Out:
# 12000.0

# %%
# who earn mininmal income?
  
print(l.index(min(l)))
# Out:
# 0

# %%
import pandas as pd

# فایل CSV رو با header بخون چون خودت با df.to_csv(..., index=False) ساختی
df = pd.read_csv("1.csv")

# پیدا کردن سطر (row) با کمترین حقوق
min_salary_row = df[df['salary'] == df['salary'].min()]

print(min_salary_row)
# Out:
#     id  name  age  child  salary
# 0  102   ali   32      5   12000
# 4  106  amir   37      3   12000

# %%
print(min_salary_row['id'].values[0])
# Out:
# 102

# %%
f = open("1.csv", "r")
next(f)  # go to the next row. it omits the header
# Out:
# 'id,name,age,child,salary\n'

# %%
salaries = []
with open("1.csv", "r") as f:
    next(f)  # رد کردن سطر اول
    for line in f:
        fields = line.strip().split(",")
        salaries.append(float(fields[4]))

min_salary = min(salaries)

print(min_salary)
# Out:
# 12000.0

# %%
# find the name and ID for min salary

with open("1.csv", "r") as f:
    next(f)
    for line in f:
        fields = line.strip().split(",")
        salary = float(fields[4])
        if salary == min_salary:
            emp_ID = fields[0]
            name = fields[1]
            print(f"Minimun salary: {salary}")
            print(f"Employee ID: {emp_ID}")
            print(f"Name: {name}")
# Out:
# Minimun salary: 12000.0
# Employee ID: 102
# Name: ali
# Minimun salary: 12000.0
# Employee ID: 106
# Name: amir

# %% [markdown]
# ## mode

# %%
# which name is more repeated among employees?

import statistics as st
f = open("1.csv","r")
l = []
next(f)

for line in f:
    l.append(float(line.split(',')[4]))

print(st.mode(l))
# Out:
# 12000.0

# %%
import statistics as st
f = open("1.csv","r")
l = []
next(f)

for line in f:
    l.append(line.split(',')[1])

print(st.mode(l))
# Out:
# ali

# %% [markdown]
# ## Median

# %%
import statistics as st
f = open("1.csv","r")
l = []
next(f)

for line in f:
    l.append(float(line.split(',')[4]))

print(sorted(l))
print(st.median(l))
# Out:
# [12000.0, 12000.0, 15000.0, 15000.0, 16000.0, 17000.0, 21000.0]
# 15000.0

# %% [markdown]
# ## standard variation from the mean

# %%
import numpy as np

# data
data = [2, 4, 4, 4, 5, 5, 7, 9]

# mean
mean = np.mean(data)

# standard variation of population
std_population = np.std(data)

# standard variation of sample
std_sample = np.std(data, ddof=1)

print("Mean :", mean)
print("Population Standard Deviation:", std_population)
print("Sample Standard Deviation :", std_sample)
# Out:
# Mean : 5.0
# Population Standard Deviation: 2.0
# Sample Standard Deviation : 2.138089935299395

# %%
import statistics as st
f = open("1.csv","r")
l = []
next(f)

for line in f:
    l.append(float(line.split(',')[4]))

print(st.mean(l))
print(st.stdev(l))
# Out:
# 15428.57142857143
# 3101.458950082625

# %%
# st devariation of mean for age

import statistics as st

f = open("1.csv","r")
l = []
next(f)

for line in f:
    l.append(float(line.split(',')[2]))


print(st.mean(l))
print(st.stdev(l))
# Out:
# 33.714285714285715
# 4.923220007078217

# %%
# st devariation of mean for age

import statistics as st
import numpy as np

f = open("1.csv","r")
l = []
next(f)

for line in f:
    l.append(float(line.split(',')[2]))

arr = np.asarray(l)

print(np.mean(arr))
print(np.amin
print(st.stdev(arr))
# Out:
# 33.714285714285715
# 4.923220007078217

# %% [markdown]
# # Data visualisation

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...

# %%
# visualisation histogram(plot)(chart) two variable : age and income

from matplotlib import pyplot as plt
import numpy as np

x = np.array([20,25,31,43])
y = np.array([2000, 23000, 42000, 46000])

plt.plot(x,y)
plt.title("Plot")
plt.xlabel("age")
plt.ylabel("income")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# give style to the plot

# visualisation plot two variable : age and income

from matplotlib import pyplot as plt
import numpy as np

x = np.array([20,25,31,43])
y = np.array([2000, 23000, 42000, 46000])


plt.plot(x,y, marker ="|") # o mean a circle  1 means another sign another signs | > < *
plt.title("Plot")
plt.xlabel("age")
plt.ylabel("income")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from matplotlib import pyplot as plt
import numpy as np

x = np.array([20,25,31,43])
y = np.array([2000, 23000, 42000, 46000])


plt.plot(x,y, ls="-") # ls maens line style - : solid line
plt.title("Plot")
plt.xlabel("age")
plt.ylabel("income")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from matplotlib import pyplot as plt
import numpy as np

x = np.array([20,25,31,43])
y = np.array([2000, 23000, 42000, 46000])


plt.plot(x,y, ls="-.") # ls maens line style -: dash dotted
plt.title("Plot")
plt.xlabel("age")
plt.ylabel("income")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from matplotlib import pyplot as plt
import numpy as np

x = np.array([20,25,31,43])
y = np.array([2000, 23000, 42000, 46000])


plt.plot(x,y, ls=":") # ls maens line style 
plt.title("Plot")
plt.xlabel("age")
plt.ylabel("income")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from matplotlib import pyplot as plt
import numpy as np

x = np.array([20,25,31,43])
y = np.array([2000, 23000, 42000, 46000])


plt.plot(x,y, ls=":", c= "r") # ls maens line style -: dash dotted  c means color 
plt.title("Plot")
plt.xlabel("age")
plt.ylabel("income")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from matplotlib import pyplot as plt
import numpy as np

x = np.array([20,25,31,43])
y = np.array([2000, 23000, 42000, 46000])


plt.plot(x,y, ls="-", c = "r", marker = "o", ms= 15, mfc = "b") # ls maens line style -: dash dotted ms = marker cise 
# c = color  mfc = marker face color  mec = marker edge color
plt.title("Plot")
plt.xlabel("age")
plt.ylabel("income")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from matplotlib import pyplot as plt
import numpy as np

x = np.array([20,25,31,43])
y = np.array([2000, 23000, 42000, 46000])


plt.plot(x,y, ls="-", c = "r", marker = "o", ms= 15, mfc = "b", mec = "b" ) # ls maens line style -: dash dotted ms = marker cise 
# c = color  mfc = marker face color  mec = marker edge color
plt.title("Plot")
plt.xlabel("age")
plt.ylabel("income")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from matplotlib import pyplot as plt
import numpy as np

x = np.array([20,25,31,43])
y = np.array([2000, 23000, 42000, 46000])


plt.plot(x,y, ls="-", c = "r", marker = "o", ms= 15, mfc = "b", mec = "b", lw =3 ) 
# ls maens line style -: dash dotted ms = marker cise 
# c = color  mfc = marker face color  mec = marker edge color lw = give width to the line
plt.title("Plot")
plt.xlabel("age")
plt.ylabel("income")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# show another plot on the plot

from matplotlib import pyplot as plt
import numpy as np

x = np.array([20,25,31,43])
y = np.array([2000, 25000, 36000, 44000])

# relation between age of cars and their speed 
x2 = np.array([20,25,30, 33])
y2 = np.array([1000, 8000, 6000, 5000])

plt.plot(x,y, x2, y2, ls="-", c = "r", marker = "o", ms= 15, mfc = "b", mec = "b", lw =3 ) 
# ls maens line style -: dash dotted ms = marker cise 
# c = color  mfc = marker face color  mec = marker edge color lw = give width to the line
plt.title("Plot")
plt.xlabel("age")
plt.ylabel("income")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# show another plot on the plot
#name =  line chart 

from matplotlib import pyplot as plt
import numpy as np

x = np.array([20,25,31,43])
y = np.array([2000, 25000, 36000, 44000])

# relation between age of cars and their speed 
x2 = np.array([20,25,30, 33])
y2 = np.array([1000, 8000, 6000, 12000])

plt.plot(x,y, x2, y2) 
# ls maens line style -: dash dotted ms = marker cise 
# c = color  mfc = marker face color  mec = marker edge color lw = give width to the line
plt.title("Plot")
plt.xlabel("age")
plt.ylabel("income")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### bar chart

# %%
#  different sorts of chart :  line chart , bar chart, histogram, pie chart , scatter plot 

from matplotlib import pyplot as plt
import numpy as np
grade= np.array(["A","B", "C", "D"])
count = np.array([12, 20, 12, 5])



plt.bar(grade, count, color = "red") 
# ls maens line style -: dash dotted ms = marker cise 
# c = color  mfc = marker face color  mec = marker edge color lw = give width to the line
plt.title("Bar chart")
plt.xlabel("grade")
plt.ylabel("count")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#  different sorts of chart :  line chart , bar chart, histogram, pie chart , scatter plot 

from matplotlib import pyplot as plt
import numpy as np
grade= np.array(["A", "B", "C", "D"])
count = np.array([12, 22,6,3])
colors = ["r","b","c","y"]
plt.bar(grade, count, color = colors) 
# ls maens line style -: dash dotted ms = marker cise 
# c = color  mfc = marker face color  mec = marker edge color lw = give width to the line
plt.title("Bar chart")
plt.xlabel("grade")
plt.ylabel("count")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## scatter chart

# %%
from matplotlib import pyplot as plt
import numpy as np
age= np.array([20,21,23,25,27,47,35,30])
salary = np.array([1000, 1300, 1500, 3200, 5100, 4200, 3000, 2500])

plt.scatter(age, salary, color = "r") 
# ls maens line style -: dash dotted ms = marker cise 
# c = color  mfc = marker face color  mec = marker edge color lw = give width to the line
plt.title("Bar chart")
plt.xlabel("grade")
plt.ylabel("count")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from matplotlib import pyplot as plt
import numpy as np

age= np.array([20,21,23,25,27,47,35,30])
salary = np.array([1000, 1300, 1500, 3200, 5100, 4200, 3000, 2500])

age1= np.array([20,25,23,25,47,49,35,27])
salary1 = np.array([1200, 1800, 1900, 3200, 5100, 4000, 3000, 2200])


# ls maens line style -: dash dotted ms = marker cise 
# c = color  mfc = marker face color  mec = marker edge color lw = give width to the line
plt.title("Bar chart")
plt.xlabel("grade")
plt.ylabel("count")
plt.show
plt.scatter(age, salary) 
plt.scatter(age1, salary1)
# ls maens line style -: dash dotted ms = marker cise 
# c = color  mfc = marker face color  mec = marker edge color lw = give width to the line
plt.title("Bar chart")
plt.xlabel("grade")
plt.ylabel("count")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Pie chart

# %%
# pie chart

from matplotlib import pyplot as plt
import numpy as np
grade= np.array(["A", "B", "C", "D"])
count = np.array([12, 22,6,3])

plt.pie(grade, count) 
# ls maens line style -: dash dotted ms = marker cise 
# c = color  mfc = marker face color  mec = marker edge color lw = give width to the line
plt.title("Pie chart")

plt.show
